# %% [markdown]
# ## Importacion de Libreria

# %%
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pandas as pd
from dotenv import load_dotenv
import os
from pathlib import Path
from io import StringIO

# %%
#Obtencion de servidor Sql

load_dotenv()  # ← carga el .env

DB_SERVER = os.getenv("DB_SERVER")
DB_NAME = os.getenv("DB_NAME")

# %%
# Conectar la info del API al SQL y guardar los datos en la base de datos para su posterior análisis.
engine = create_engine(
    f"mssql+pyodbc://{DB_SERVER}/{DB_NAME}"
    f"?driver=ODBC+Driver+17+for+SQL+Server&trusted_connection=yes"
)

# %% [markdown]
# ## Informacion de los partidos de la Liga

# %%
carpeta = r'C:\Users\brger\OneDrive\Desktop\Project\Football_Prediction\Data\raw'
temporadas = list(Path(carpeta).glob('*.csv'))
temporadas
# Out:
# [WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0001.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0102.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0203.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0304.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0405.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0506.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0607.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0708.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0809.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_0910.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1011.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1112.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1213.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1314.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1415.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1516.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1617.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1718.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1819.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_1920.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2021.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2122.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2223.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2324.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2425.csv'),
#  WindowsPath('C:/Users/brger/OneDrive/Desktop/Project/Football_Prediction/Data/raw/SP1_2526.csv')]

# %%
df1 = pd.DataFrame()

for temporada in temporadas:
    Campaña = temporada.stem.split('_')[1]
    print(f"Procesando temporada: {Campaña}")
    try:
        with open(temporada, encoding='utf-8') as f:
            contenido = f.read()
    except UnicodeDecodeError:
        with open(temporada, encoding='latin-1') as f:
            contenido = f.read()

    lineas = contenido.splitlines()
    lineas_limpias = [linea.rstrip(',') for linea in lineas]
    texto_limpio = '\n'.join(lineas_limpias)

    df = pd.read_csv(StringIO(texto_limpio), sep=',')
    df['temporada'] = Campaña          # primero asigna la columna
    df.drop(columns=['Div'], inplace=True, errors='ignore')  # luego elimina Div
    df1 = pd.concat([df1, df], ignore_index=True)  # finalmente concatena
    print(f"Total de datos cargados {Campaña}: {len(df)}")

print(f"✅ Total filas: {len(df1)}")
# Out:
# Procesando temporada: 0001
# Total de datos cargados 0001: 380
# Procesando temporada: 0102
# Total de datos cargados 0102: 380
# Procesando temporada: 0203
# Total de datos cargados 0203: 380
# Procesando temporada: 0304
# Total de datos cargados 0304: 380
# Procesando temporada: 0405
# Total de datos cargados 0405: 380
# Procesando temporada: 0506
# Total de datos cargados 0506: 380
# Procesando temporada: 0607
# Total de datos cargados 0607: 380
# Procesando temporada: 0708
# Total de datos cargados 0708: 380
# Procesando temporada: 0809
# Total de datos cargados 0809: 380
# Procesando temporada: 0910
# Total de datos cargados 0910: 380
# Procesando temporada: 1011
# Total de datos cargados 1011: 380
# Procesando temporada: 1112
# Total de datos cargados 1112: 380
# Procesando temporada: 1213
# Total de datos cargados 1213: 380
# Procesando temporada: 1314
# Total de datos cargados 1314: 380
# Procesando temporada: 1415
# Total de datos cargados 1415: 380
# Procesando temporada: 1516
# Total de datos cargados 1516: 380
# Procesando temporada: 1617
# Total de datos cargados 1617: 380
# Procesando temporada: 1718
# Total de datos cargados 1718: 380
# Procesando temporada: 1819
# Total de datos cargados 1819: 380
# Procesando temporada: 1920
# Total de datos cargados 1920: 380
# Procesando temporada: 2021
# Total de datos cargados 2021: 380
# Procesando temporada: 2122
# Total de datos cargados 2122: 380
# Procesando temporada: 2223
# Total de datos cargados 2223: 380
# Procesando temporada: 2324
# Total de datos cargados 2324: 380
# Procesando temporada: 2425
# Total de datos cargados 2425: 380
# Procesando temporada: 2526
# Total de datos cargados 2526: 270
# ✅ Total filas: 9770

# %%
df1.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9770 entries, 0 to 9769
# Data columns (total 206 columns):
#  #    Column     Non-Null Count  Dtype
# ---   ------     --------------  -----
#  0    Date       9770 non-null   object
#  1    HomeTeam   9770 non-null   object
#  2    AwayTeam   9770 non-null   object
#  3    FTHG       9770 non-null   int64
#  4    FTAG       9770 non-null   int64
#  5    FTR        9770 non-null   object
#  6    HTHG       9770 non-null   int64
#  7    HTAG       9770 non-null   int64
#  8    HTR        9770 non-null   object
#  9    GBH        4841 non-null   float64
#  10   GBD        4841 non-null   float64
#  11   GBA        4841 non-null   float64
#  12   IWH        8908 non-null   float64
#  13   IWD        8908 non-null   float64
#  14   IWA        8908 non-null   float64
#  15   LBH        6988 non-null   float64
#  16   LBD        6988 non-null   float64
#  17   LBA        6988 non-null   float64
#  18   SBH        4507 non-null   float64
#  19   SBD        4507 non-null   float64
#  20   SBA        4507 non-null   float64
#  21   WHH        9198 non-null   float64
#  22   WHD        9198 non-null   float64
#  23   WHA        9198 non-null   float64
#  24   temporada  9770 non-null   object
#  25   SYH        356 non-null    float64
#  26   SYD        356 non-null    float64
#  27   SYA        356 non-null    float64
#  28   B365H      9004 non-null   float64
#  29   B365D      9004 non-null   float64
#  30   B365A      9004 non-null   float64
#  31   SOH        746 non-null    float64
#  32   SOD        746 non-null    float64
#  33   SOA        746 non-null    float64
#  34   GB>2.5     1087 non-null   float64
#  35   GB<2.5     1087 non-null   float64
#  36   B365>2.5   3505 non-null   float64
#  37   B365<2.5   3505 non-null   float64
#  38   GBAHH      737 non-null    float64
#  39   GBAHA      737 non-null    float64
#  40   GBAH       737 non-null    float64
#  41   LBAHH      690 non-null    float64
#  42   LBAHA      690 non-null    float64
#  43   LBAH       690 non-null    float64
#  44   B365AHH    3279 non-null   float64
#  45   B365AHA    3279 non-null   float64
#  46   B365AH     740 non-null    float64
#  47   BWH        8089 non-null   float64
#  48   BWD        8089 non-null   float64
#  49   BWA        8089 non-null   float64
#  50   HS         7870 non-null   float64
#  51   AS         7870 non-null   float64
#  52   HST        7870 non-null   float64
#  53   AST        7870 non-null   float64
#  54   HF         7870 non-null   float64
#  55   AF         7870 non-null   float64
#  56   HC         7870 non-null   float64
#  57   AC         7870 non-null   float64
#  58   HY         7870 non-null   float64
#  59   AY         7870 non-null   float64
#  60   HR         7870 non-null   float64
#  61   AR         7870 non-null   float64
#  62   SJH        3447 non-null   float64
#  63   SJD        3447 non-null   float64
#  64   SJA        3447 non-null   float64
#  65   VCH        7215 non-null   float64
#  66   VCD        7215 non-null   float64
#  67   VCA        7215 non-null   float64
#  68   Bb1X2      5320 non-null   float64
#  69   BbMxH      5320 non-null   float64
#  70   BbAvH      5320 non-null   float64
#  71   BbMxD      5320 non-null   float64
#  72   BbAvD      5320 non-null   float64
#  73   BbMxA      5320 non-null   float64
#  74   BbAvA      5320 non-null   float64
#  75   BbOU       5320 non-null   float64
#  76   BbMx>2.5   5319 non-null   float64
#  77   BbAv>2.5   5319 non-null   float64
#  78   BbMx<2.5   5319 non-null   float64
#  79   BbAv<2.5   5319 non-null   float64
#  80   BbAH       5310 non-null   float64
#  81   BbAHh      5310 non-null   float64
#  82   BbMxAHH    5310 non-null   float64
#  83   BbAvAHH    5310 non-null   float64
#  84   BbMxAHA    5310 non-null   float64
#  85   BbAvAHA    5310 non-null   float64
#  86   BSH        2280 non-null   float64
#  87   BSD        2280 non-null   float64
#  88   BSA        2280 non-null   float64
#  89   PSH        5123 non-null   float64
#  90   PSD        5123 non-null   float64
#  91   PSA        5123 non-null   float64
#  92   PSCH       5127 non-null   float64
#  93   PSCD       5127 non-null   float64
#  94   PSCA       5127 non-null   float64
#  95   Time       2550 non-null   object
#  96   MaxH       2550 non-null   float64
#  97   MaxD       2550 non-null   float64
#  98   MaxA       2550 non-null   float64
#  99   AvgH       2550 non-null   float64
#  100  AvgD       2550 non-null   float64
#  101  AvgA       2550 non-null   float64
#  102  P>2.5      2461 non-null   float64
#  103  P<2.5      2461 non-null   float64
#  104  Max>2.5    2550 non-null   float64
#  105  Max<2.5    2550 non-null   float64
#  106  Avg>2.5    2550 non-null   float64
#  107  Avg<2.5    2550 non-null   float64
#  108  AHh        2550 non-null   float64
#  109  PAHH       2465 non-null   float64
#  110  PAHA       2465 non-null   float64
#  111  MaxAHH     2550 non-null   float64
#  112  MaxAHA     2550 non-null   float64
#  113  AvgAHH     2550 non-null   float64
#  114  AvgAHA     2550 non-null   float64
#  115  B365CH     2550 non-null   float64
#  116  B365CD     2550 non-null   float64
#  117  B365CA     2550 non-null   float64
#  118  BWCH       2390 non-null   float64
#  119  BWCD       2390 non-null   float64
#  120  BWCA       2390 non-null   float64
#  121  IWCH       1704 non-null   float64
#  122  IWCD       1704 non-null   float64
#  123  IWCA       1704 non-null   float64
#  124  WHCH       2178 non-null   float64
#  125  WHCD       2178 non-null   float64
#  126  WHCA       2178 non-null   float64
#  127  VCCH       1900 non-null   float64
#  128  VCCD       1900 non-null   float64
#  129  VCCA       1900 non-null   float64
#  130  MaxCH      2550 non-null   float64
#  131  MaxCD      2550 non-null   float64
#  132  MaxCA      2550 non-null   float64
#  133  AvgCH      2550 non-null   float64
#  134  AvgCD      2550 non-null   float64
#  135  AvgCA      2550 non-null   float64
#  136  B365C>2.5  2550 non-null   float64
#  137  B365C<2.5  2550 non-null   float64
#  138  PC>2.5     2466 non-null   float64
#  139  PC<2.5     2466 non-null   float64
#  140  MaxC>2.5   2550 non-null   float64
#  141  MaxC<2.5   2550 non-null   float64
#  142  AvgC>2.5   2550 non-null   float64
#  143  AvgC<2.5   2550 non-null   float64
#  144  AHCh       2550 non-null   float64
#  145  B365CAHH   2549 non-null   float64
#  146  B365CAHA   2549 non-null   float64
#  147  PCAHH      2469 non-null   float64
#  148  PCAHA      2469 non-null   float64
#  149  MaxCAHH    2550 non-null   float64
#  150  MaxCAHA    2550 non-null   float64
#  151  AvgCAHH    2550 non-null   float64
#  152  AvgCAHA    2550 non-null   float64
#  153  BFH        380 non-null    float64
#  154  BFD        380 non-null    float64
#  155  BFA        380 non-null    float64
#  156  1XBH       370 non-null    float64
#  157  1XBD       370 non-null    float64
#  158  1XBA       370 non-null    float64
#  159  BFEH       650 non-null    float64
#  160  BFED       650 non-null    float64
#  161  BFEA       650 non-null    float64
#  162  BFE>2.5    643 non-null    float64
#  163  BFE<2.5    643 non-null    float64
#  164  BFEAHH     650 non-null    float64
#  165  BFEAHA     650 non-null    float64
#  166  BFCH       380 non-null    float64
#  167  BFCD       380 non-null    float64
#  168  BFCA       380 non-null    float64
#  169  1XBCH      380 non-null    float64
#  170  1XBCD      380 non-null    float64
#  171  1XBCA      380 non-null    float64
#  172  BFECH      650 non-null    float64
#  173  BFECD      650 non-null    float64
#  174  BFECA      650 non-null    float64
#  175  BFEC>2.5   650 non-null    float64
#  176  BFEC<2.5   650 non-null    float64
#  177  BFECAHH    650 non-null    float64
#  178  BFECAHA    650 non-null    float64
#  179  BFDH       270 non-null    float64
#  180  BFDD       270 non-null    float64
#  181  BFDA       270 non-null    float64
#  182  BMGMH      270 non-null    float64
#  183  BMGMD      270 non-null    float64
#  184  BMGMA      270 non-null    float64
#  185  BVH        270 non-null    float64
#  186  BVD        270 non-null    float64
#  187  BVA        270 non-null    float64
#  188  CLH        219 non-null    float64
#  189  CLD        219 non-null    float64
#  190  CLA        219 non-null    float64
#  191  BFDCH      270 non-null    float64
#  192  BFDCD      270 non-null    float64
#  193  BFDCA      270 non-null    float64
#  194  BMGMCH     270 non-null    float64
#  195  BMGMCD     270 non-null    float64
#  196  BMGMCA     270 non-null    float64
#  197  BVCH       270 non-null    float64
#  198  BVCD       270 non-null    float64
#  199  BVCA       270 non-null    float64
#  200  CLCH       216 non-null    float64
#  201  CLCD       216 non-null    float64
#  202  CLCA       216 non-null    float64
#  203  LBCH       216 non-null    float64
#  204  LBCD       216 non-null    float64
#  205  LBCA       216 non-null    float64
# dtypes: float64(195), int64(4), object(7)
# memory usage: 15.4+ MB

# %%
df1
# Out:
#             Date     HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG HTR  \
# 0       09/09/00    Barcelona      Malaga     2     1   H     2     0   H
# 1       09/09/00    La Coruna  Ath Bilbao     2     0   H     0     0   D
# 2       09/09/00  Real Madrid    Valencia     2     1   H     0     0   D
# 3       09/09/00     Sociedad   Santander     2     2   D     0     0   D
# 4       09/09/00     Zaragoza     Espanol     1     2   A     0     0   D
# ...          ...          ...         ...   ...   ...  ..   ...   ...  ..
# 9765  08/03/2026   Villarreal       Elche     2     1   H     2     0   H
# 9766  08/03/2026       Getafe       Betis     2     0   H     2     0   H
# 9767  08/03/2026      Sevilla   Vallecano     1     1   D     1     0   H
# 9768  08/03/2026     Valencia      Alaves     3     2   H     0     1   A
# 9769  09/03/2026      Espanol      Oviedo     1     1   D     1     1   D
#
#        GBH  ...  BMGMCA  BVCH  BVCD  BVCA  CLCH  CLCD  CLCA  LBCH  LBCD  LBCA
# 0     1.28  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1     1.51  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2     1.65  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3     1.85  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4     1.70  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...    ...  ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 9765   NaN  ...    6.75  1.44  4.75  7.00   NaN   NaN   NaN   NaN   NaN   NaN
# 9766   NaN  ...    2.95  2.70  2.80  3.10   NaN   NaN   NaN   NaN   NaN   NaN
# 9767   NaN  ...    2.95  2.50  3.13  3.00   NaN   NaN   NaN   NaN   NaN   NaN
# 9768   NaN  ...    3.95  2.05  3.10  4.10   NaN   NaN   NaN   NaN   NaN   NaN
# 9769   NaN  ...    4.40  1.95  3.20  4.33  1.95  3.25   4.2  1.95  3.25   4.0
#
# [9770 rows x 206 columns]

# %%
df1.groupby('temporada')['HomeTeam'].count()
# Out:
# temporada
# 0001    380
# 0102    380
# 0203    380
# 0304    380
# 0405    380
# 0506    380
# 0607    380
# 0708    380
# 0809    380
# 0910    380
# 1011    380
# 1112    380
# 1213    380
# 1314    380
# 1415    380
# 1516    380
# 1617    380
# 1718    380
# 1819    380
# 1920    380
# 2021    380
# 2122    380
# 2223    380
# 2324    380
# 2425    380
# 2526    270
# Name: HomeTeam, dtype: int64

# %%
for season in df1.temporada.unique():
    df_season = df1[df1['temporada'] == season]
    
    nulos = (df_season.isnull().sum() / len(df_season) * 100).sort_values(ascending=False)
    nulos = nulos[nulos > 1]

    plt.figure(figsize=(20, 5))
    nulos.plot(kind='bar')
    plt.title(f"% de valores faltantes por Temporada {season}")
    plt.ylabel("% nulos")
    plt.xticks(rotation=90, fontsize=7)
    plt.tight_layout()
    plt.show()

# %%
# Eliminar columnas Unnamed
unnamed = [col for col in df1.columns if 'Unnamed' in col]
print(f"Columnas a eliminar: {unnamed}")
df1.drop(columns=unnamed, inplace=True)
print(f"✅ Columnas restantes: {df1.shape[1]}")
# Out:
# Columnas a eliminar: []
# ✅ Columnas restantes: 206

# %%
# Ver % de nulos solo de columnas importantes
columnas_clave = ['Date','HomeTeam','AwayTeam','FTHG','FTAG','FTR',
                  'HTHG','HTAG','HTR','HS','AS','HST','AST',
                  'HC','AC','HY','AY','HR','AR','temporada']

nulos = df1[columnas_clave].isnull().sum()
nulos_pct = (nulos / len(df1) * 100).round(1)
pd.DataFrame({'nulos': nulos, '%': nulos_pct})
# Out:
#            nulos     %
# Date           0   0.0
# HomeTeam       0   0.0
# AwayTeam       0   0.0
# FTHG           0   0.0
# FTAG           0   0.0
# FTR            0   0.0
# HTHG           0   0.0
# HTAG           0   0.0
# HTR            0   0.0
# HS          1900  19.4
# AS          1900  19.4
# HST         1900  19.4
# AST         1900  19.4
# HC          1900  19.4
# AC          1900  19.4
# HY          1900  19.4
# AY          1900  19.4
# HR          1900  19.4
# AR          1900  19.4
# temporada      0   0.0

# %% [markdown]
# Los nulos corresponden de las temporadas 2000/2001 hasta el 2004/2005 porque no se registraban esos indicadores en su momento

# %%
# Corregir Date
df1['Date'] = pd.to_datetime(df1['Date'], dayfirst=True, errors='coerce')

df1['Time'] = pd.to_datetime(df1['Time'], format='%H:%M', errors='coerce').dt.time
# Out:
# C:\Users\brger\AppData\Local\Temp\ipykernel_18584\436160361.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df1['Date'] = pd.to_datetime(df1['Date'], dayfirst=True, errors='coerce')

# %%
df1['Date'].dtype  # debe decir datetime64[ns]
# Out:
# dtype('<M8[ns]')

# %%
# Columnas Asian Handicap a eliminar
asian_handicap = [col for col in df1.columns if 'AH' in col or 'AHh' in col.lower()]
print(f"Columnas AH a eliminar: {asian_handicap}")

df1.drop(columns=asian_handicap, inplace=True)
print(f"✅ Columnas restantes: {df1.shape[1]}")
# Out:
# Columnas AH a eliminar: ['GBAHH', 'GBAHA', 'GBAH', 'LBAHH', 'LBAHA', 'LBAH', 'B365AHH', 'B365AHA', 'B365AH', 'BbAH', 'BbAHh', 'BbMxAHH', 'BbAvAHH', 'BbMxAHA', 'BbAvAHA', 'AHh', 'PAHH', 'PAHA', 'MaxAHH', 'MaxAHA', 'AvgAHH', 'AvgAHA', 'AHCh', 'B365CAHH', 'B365CAHA', 'PCAHH', 'PCAHA', 'MaxCAHH', 'MaxCAHA', 'AvgCAHH', 'AvgCAHA', 'BFEAHH', 'BFEAHA', 'BFECAHH', 'BFECAHA']
# ✅ Columnas restantes: 171

# %% [markdown]
# ## Armar DIM_EQUIPO

# %%
# combinar los equipos de ambas columnas y sacar los únicos
equipos = pd.concat([df1['HomeTeam'], df1['AwayTeam']]).unique()

# %%
equipos
# Out:
# array(['Barcelona', 'La Coruna', 'Real Madrid', 'Sociedad', 'Zaragoza',
#        'Las Palmas', 'Mallorca', 'Numancia', 'Osasuna', 'Villarreal',
#        'Ath Bilbao', 'Malaga', 'Santander', 'Valencia', 'Valladolid',
#        'Alaves', 'Celta', 'Espanol', 'Oviedo', 'Vallecano', 'Sevilla',
#        'Tenerife', 'Betis', 'Recreativo', 'Ath Madrid', 'Albacete',
#        'Murcia', 'Getafe', 'Levante', 'Cadiz', 'Gimnastic', 'Almeria',
#        'Sp Gijon', 'Xerez', 'Hercules', 'Granada', 'Elche', 'Eibar',
#        'Cordoba', 'Leganes', 'Girona', 'Huesca'], dtype=object)

# %%
dim_equipo = pd.DataFrame({
    'nombre': sorted(equipos)
})

# %% [markdown]
# ## Armar la bd de DIM_FECHAS

# %%
dim_fecha = pd.DataFrame({
    'fecha'     : df1['Date'].unique()
})

# %%
pd.merge(dim_fecha,df1,left_on='fecha',right_on='Date',how='right')[['temporada']]
# Out:
#      temporada
# 0         0001
# 1         0001
# 2         0001
# 3         0001
# 4         0001
# ...        ...
# 9765      2526
# 9766      2526
# 9767      2526
# 9768      2526
# 9769      2526
#
# [9770 rows x 1 columns]

# %%
dim_fecha['Año'] = dim_fecha['fecha'].dt.year
dim_fecha['Mes'] = dim_fecha['fecha'].dt.month
dim_fecha['Nombre_Mes']  = dim_fecha['fecha'].dt.month_name(locale = 'es')
dim_fecha['Semana']     = dim_fecha['fecha'].dt.isocalendar().week.astype(int)
dim_fecha['Dia'] = dim_fecha['fecha'].dt.day
dim_fecha['Nombre_Dia'] = dim_fecha['fecha'].dt.day_name(locale='es')
fecha_temporada = df1[['Date','temporada']].drop_duplicates()
dim_fecha = dim_fecha.merge(fecha_temporada, left_on='fecha', right_on='Date', how='left').drop(columns='Date')

# %%
dim_fecha
# Out:
#           fecha   Año  Mes  Nombre_Mes  Semana  Dia Nombre_Dia temporada
# 0    2000-09-09  2000    9  Septiembre      36    9     Sábado      0001
# 1    2000-09-10  2000    9  Septiembre      36   10    Domingo      0001
# 2    2000-09-16  2000    9  Septiembre      37   16     Sábado      0001
# 3    2000-09-17  2000    9  Septiembre      37   17    Domingo      0001
# 4    2000-09-23  2000    9  Septiembre      38   23     Sábado      0001
# ...         ...   ...  ...         ...     ...  ...        ...       ...
# 2828 2026-03-04  2026    3       Marzo      10    4  Miércoles      2526
# 2829 2026-03-06  2026    3       Marzo      10    6    Viernes      2526
# 2830 2026-03-07  2026    3       Marzo      10    7     Sábado      2526
# 2831 2026-03-08  2026    3       Marzo      10    8    Domingo      2526
# 2832 2026-03-09  2026    3       Marzo      11    9      Lunes      2526
#
# [2833 rows x 8 columns]

# %% [markdown]
# ## Conectar Las DIM  en la bd de PARTIDOS

# %%
#DIM_EQUIPO
dim_equipo = dim_equipo.reset_index(drop=True)
dim_equipo['id_equipo'] = dim_equipo.index + 1

# %%
fact_partido = df1.merge(dim_equipo, left_on='HomeTeam', right_on='nombre', how='left')
fact_partido = fact_partido.rename(columns={'id_equipo': 'id_equipo_local'}).drop(columns='nombre')

fact_partido = fact_partido.merge(dim_equipo, left_on='AwayTeam', right_on='nombre', how='left')
fact_partido = fact_partido.rename(columns={'id_equipo': 'id_equipo_visitante'}).drop(columns='nombre')

# %%
fact_partido[['HomeTeam','id_equipo_local','AwayTeam','id_equipo_visitante']].head()
# Out:
#       HomeTeam  id_equipo_local    AwayTeam  id_equipo_visitante
# 0    Barcelona                6      Malaga                   24
# 1    La Coruna               20  Ath Bilbao                    4
# 2  Real Madrid               30    Valencia                   37
# 3     Sociedad               34   Santander                   32
# 4     Zaragoza               42     Espanol                   13

# %%
print("dim_equipo:", dim_equipo.columns.tolist())
print("dim_fecha:", dim_fecha.columns.tolist())
print("fact_partido:", fact_partido.columns.tolist())
# Out:
# dim_equipo: ['nombre', 'id_equipo']
# dim_fecha: ['fecha', 'Año', 'Mes', 'Nombre_Mes', 'Semana', 'Dia', 'Nombre_Dia', 'temporada']
# fact_partido: ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'GBH', 'GBD', 'GBA', 'IWH', 'IWD', 'IWA', 'LBH', 'LBD', 'LBA', 'SBH', 'SBD', 'SBA', 'WHH', 'WHD', 'WHA', 'temporada', 'SYH', 'SYD', 'SYA', 'B365H', 'B365D', 'B365A', 'SOH', 'SOD', 'SOA', 'GB>2.5', 'GB<2.5', 'B365>2.5', 'B365<2.5', 'BWH', 'BWD', 'BWA', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'SJH', 'SJD', 'SJA', 'VCH', 'VCD', 'VCA', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5', 'BSH', 'BSD', 'BSA', 'PSH', 'PSD', 'PSA', 'PSCH', 'PSCD', 'PSCA', 'Time', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'BFH', 'BFD', 'BFA', '1XBH', '1XBD', '1XBA', 'BFEH', 'BFED', 'BFEA', 'BFE>2.5', 'BFE<2.5', 'BFCH', 'BFCD', 'BFCA', '1XBCH', '1XBCD', '1XBCA', 'BFECH', 'BFECD', 'BFECA', 'BFEC>2.5', 'BFEC<2.5', 'BFDH', 'BFDD', 'BFDA', 'BMGMH', 'BMGMD', 'BMGMA', 'BVH', 'BVD', 'BVA', 'CLH', 'CLD', 'CLA', 'BFDCH', 'BFDCD', 'BFDCA', 'BMGMCH', 'BMGMCD', 'BMGMCA', 'BVCH', 'BVCD', 'BVCA', 'CLCH', 'CLCD', 'CLCA', 'LBCH', 'LBCD', 'LBCA', 'id_equipo_local', 'id_equipo_visitante']

# %%
# Columnas Asian Handicap a eliminar
asian_handicap = [col for col in fact_partido.columns if 'AH' in col or 'AHh' in col.lower()]
print(f"Columnas AH a eliminar: {asian_handicap}")

fact_partido.drop(columns=asian_handicap, inplace=True)
print(f"✅ Columnas restantes: {fact_partido.shape[1]}")
# Out:
# Columnas AH a eliminar: []
# ✅ Columnas restantes: 173

# %%
# Closing reales — las que ya tienen una C antes de H/D/A
closing_reales = [col for col in fact_partido.columns 
                  if col.endswith('CH') or col.endswith('CD') or col.endswith('CA')
                  if col not in ['VCH','VCD','VCA','PSCH','PSCD','PSCA','BFCH','BFCD','BFCA']]

print(f"Closing reales: {len(closing_reales)}")
print(closing_reales)
# Out:
# Closing reales: 42
# ['B365CH', 'B365CD', 'B365CA', 'BWCH', 'BWCD', 'BWCA', 'IWCH', 'IWCD', 'IWCA', 'WHCH', 'WHCD', 'WHCA', 'VCCH', 'VCCD', 'VCCA', 'MaxCH', 'MaxCD', 'MaxCA', 'AvgCH', 'AvgCD', 'AvgCA', '1XBCH', '1XBCD', '1XBCA', 'BFECH', 'BFECD', 'BFECA', 'BFDCH', 'BFDCD', 'BFDCA', 'BMGMCH', 'BMGMCD', 'BMGMCA', 'BVCH', 'BVCD', 'BVCA', 'CLCH', 'CLCD', 'CLCA', 'LBCH', 'LBCD', 'LBCA']

# %%
fact_partido.drop(columns=closing_reales, inplace=True)
print(f"✅ Columnas restantes: {fact_partido.shape[1]}")
# Out:
# ✅ Columnas restantes: 131

# %%
# Casas individuales a eliminar
casas_individuales = [
    'GBH','GBD','GBA',
    'IWH','IWD','IWA',
    'LBH','LBD','LBA',
    'SBH','SBD','SBA',
    'WHH','WHD','WHA',
    'SYH','SYD','SYA',
    'SOH','SOD','SOA',
    'BWH','BWD','BWA',
    'SJH','SJD','SJA',
    'VCH','VCD','VCA',
    'BSH','BSD','BSA',
    'PSH','PSD','PSA',
    'PSCH','PSCD','PSCA',
    'BFH','BFD','BFA',
    '1XBH','1XBD','1XBA',
    'BFEH','BFED','BFEA',
    'BFCH','BFCD','BFCA',
    'BFECH','BFECD','BFECA',
    'BFDH','BFDD','BFDA',
    'BMGMH','BMGMD','BMGMA',
    'BVH','BVD','BVA',
    'CLH','CLD','CLA',
]

# Solo eliminar las que existen en el DataFrame
casas_a_eliminar = [col for col in casas_individuales if col in fact_partido.columns]
fact_partido.drop(columns=casas_a_eliminar, inplace=True)
print(f"✅ Columnas restantes: {fact_partido.shape[1]}")
print(fact_partido.columns.tolist())
# Out:
# ✅ Columnas restantes: 68
# ['Date', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR', 'HTHG', 'HTAG', 'HTR', 'temporada', 'B365H', 'B365D', 'B365A', 'GB>2.5', 'GB<2.5', 'B365>2.5', 'B365<2.5', 'HS', 'AS', 'HST', 'AST', 'HF', 'AF', 'HC', 'AC', 'HY', 'AY', 'HR', 'AR', 'Bb1X2', 'BbMxH', 'BbAvH', 'BbMxD', 'BbAvD', 'BbMxA', 'BbAvA', 'BbOU', 'BbMx>2.5', 'BbAv>2.5', 'BbMx<2.5', 'BbAv<2.5', 'Time', 'MaxH', 'MaxD', 'MaxA', 'AvgH', 'AvgD', 'AvgA', 'P>2.5', 'P<2.5', 'Max>2.5', 'Max<2.5', 'Avg>2.5', 'Avg<2.5', 'B365C>2.5', 'B365C<2.5', 'PC>2.5', 'PC<2.5', 'MaxC>2.5', 'MaxC<2.5', 'AvgC>2.5', 'AvgC<2.5', 'BFE>2.5', 'BFE<2.5', 'BFEC>2.5', 'BFEC<2.5', 'id_equipo_local', 'id_equipo_visitante']

# %% [markdown]
# ## Cargar los datos al SQL

# %%
# Primero las dims, luego el fact
dim_equipo[['nombre']].to_sql('dim_equipo', engine, if_exists='append', index=False)
print("✅ dim_equipo cargada")

dim_fecha.to_sql('dim_fecha', engine, if_exists='append', index=False)
print("✅ dim_fecha cargada")

fact_partido.to_sql('fact_partido', engine, if_exists='append', index=False)
print("✅ fact_partido cargada")
# Out:
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\io\sql.py:1648: SAWarning: Unrecognized server version info '17.0.1000.7'.  Some SQL Server features may not function properly.
#   con = self.exit_stack.enter_context(con.connect())
# ✅ dim_equipo cargada
# ✅ dim_fecha cargada
# ✅ fact_partido cargada
